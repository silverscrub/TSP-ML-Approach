# %%
library("TSP")
concorde_path("/home/LC/mailo01/concorde/TSP")
# Out:
# found: concorde concorde.c concorde.o

# %%
x <- c(66.0286013,39.3790576,21.1773746,77.5882428,71.1837244 ,1.0135210, 16.1504255, 63.4434737, 92.0068322,20.7189167,86.4426628 ,3.7500414, 38.1142469, 63.1106560, 12.0973343, 23.3824655,98.9741634, 42.0541264, 4.0314784, 66.9395995, 88.1795595, 45.9702238, 7.4341686, 31.7536285, 67.0222588, 11.0237239, 37.1768174,27.0024378,86.2349807, 20.6655088, 16.0991802, 5.4056006, 9.4610725, 14.2269015, 78.4655981, 82.8958699,41.6429370, 23.0891302, 57.8082254, 93.4258363, 3.3816993, 18.9950647, 84.2268950, 86.9775060, 19.8062613, 53.0813889, 51.6709170, 54.8412989, 93.4272593, 55.1171208, 3.5776241, 97.8357936, 75.0131897, 76.6457750 ,71.3476800, 54.0647822, 90.5792187, 65.7854134,  0.9311936, 93.9049996, 29.0985335, 34.4120563, 85.4146785, 74.8047235, 10.4497189, 94.3855914, 97.2498295, 47.1341220,  9.5583925, 15.3619712, 25.0885179, 90.1001143, 44.8037491, 54.7557628,  4.0850146, 85.0039131, 31.9295639, 42.6588063, 76.8956458, 16.4809630, 63.3993582, 71.2888767, 67.0827814, 50.1566765, 41.4043843, 10.5992856, 51.3255481, 22.4196033, 85.2373159, 85.1121625, 30.2504256, 78.8206443, 67.1956610, 39.2990186, 98.1536849, 77.7398234, 4.6015654, 41.7224485, 20.0525639, 55.7633181)
y <- c(98.864174, 34.641777, 94.882852, 99.839651 ,64.295963, 73.575928, 56.588939,31.697917, 17.303138, 29.455349 ,41.523827 ,24.166656, 76.600278, 57.504692,27.672449, 62.978299, 35.062115 ,29.238737, 42.957346, 92.556043, 12.920511,36.446804, 64.987270, 61.514423, 96.609981, 71.894708 , 7.524736 , 87.322929,15.280987 ,40.693352 ,94.978108 ,94.180244 ,80.573157 , 4.048710, 78.898112, 18.535070 ,50.604258, 33.670785, 99.088625 ,80.361332 ,62.254157, 40.378505, 22.697444, 95.292455 ,42.403228, 60.532319, 95.319555, 24.226552, 77.459421, 27.346486, 21.920394, 67.674919, 53.374669, 21.492838, 4.030567, 47.408183, 55.384157 , 5.210343, 44.540615, 73.028997, 41.881741, 78.354676, 65.545989, 81.963678, 56.063805, 42.143781 , 8.387093, 81.078070, 96.080515, 92.407956, 47.013862, 31.908493, 28.811751, 68.047019, 76.491267, 12.957545, 38.174843, 96.587903, 55.514238, 89.145257, 56.193173, 11.613649,97.714335 ,48.438556, 42.434011 ,67.214081 , 8.505618, 68.676182, 27.621297, 56.297978,26.935836,63.058531,72.158684,20.891912 ,8.879785,50.327153 ,29.410796, 75.159615,55.131152,69.646247)

# %%
pts <- data.frame(x,y)

# %%
etsp <- ETSP(pts)

# %%
tour <- solve_TSP(etsp, method="concorde", control=list(clo="-v -V"))
# Out:
# Used control parameters:
# clo	 =  -v -V
# exe	 =  /home/LC/mailo01/concorde/TSP/concorde
# precision	 =  6
# verbose	 =  TRUE
# keep_files	 =  FALSE

# %%
#run 1
print(tour)
print(tour_length(tour))
print(as.integer(tour))
# Out:
# object of class ‘TOUR’
# result of method ‘concorde’ for 100 cities
# tour length: 945.187
# [1] 945.187
#   [1]   1  25  83   4  44  20  64  35  40  49  52  63  60  57  90  92  79  96
#  [19]  53  11  66  17  89  72   9  29  95  67  76  21  54  43  36  82  55  58
#  [37]  87  27  94  48  50   8  22  85   2  18  73  91  61  77  30  45  42  38
#  [55]  10  34  51  12  97  15  19  59  41  23  65  99  16   7  24  71  37  56
#  [73]  84  46  81  14   5  93 100  74  68  98  13  62  88  26  86   6  75  33
#  [91]  32  69  31  70  80   3  28  78  47  39

# %%
#run 2
print(tour)
print(tour_length(tour))
print(as.integer(tour))
# Out:
# object of class ‘TOUR’
# result of method ‘concorde’ for 100 cities
# tour length: 945.187
# [1] 945.187
#   [1]   1  25  83   4  44  20  64  35  40  49  52  63  60  57  90  92  79  96
#  [19]  53  11  66  17  89  72   9  29  95  67  76  21  54  43  36  82  55  58
#  [37]  87  27  94  48  50   8  22  85   2  18  73  91  61  77  30  45  42  38
#  [55]  10  34  51  12  97  15  19  59  41  23  65  99  16   7  24  71  37  56
#  [73]  84  46  81  14   5  93 100  74  68  98  13  62  88  26  86   6  75  33
#  [91]  32  69  31  70  80   3  28  78  47  39

# %%
plot(etsp, tour)
# Out:
# plot without title

# %%
data("USCA50")

# %%
tour <- solve_TSP(USCA50, method="concorde")
tour
print(tour)
# Out:
# Used control parameters:
# clo	 =
# exe	 =  /home/LC/mailo01/concorde/TSP/concorde
# precision	 =  6
# verbose	 =  TRUE
# keep_files	 =  FALSE
# object of class ‘TOUR’
# result of method ‘concorde’ for 50 cities
# tour length: 14497
# object of class ‘TOUR’
# result of method ‘concorde’ for 50 cities
# tour length: 14497

# %%
tour <- solve_TSP(USCA50, method="concorde")
tour
print(tour)
# Out:
# Used control parameters:
# clo	 =
# exe	 =  /home/LC/mailo01/concorde/TSP/concorde
# precision	 =  6
# verbose	 =  TRUE
# keep_files	 =  FALSE
# object of class ‘TOUR’
# result of method ‘concorde’ for 50 cities
# tour length: 14497
# object of class ‘TOUR’
# result of method ‘concorde’ for 50 cities
# tour length: 14497

# %%
rbu <- read_TSPLIB("/home/LC/mailo01/TSP-ML-Approach/src/firstRun/rbu737.tsp")
rbu
# Out:
# ERROR while rich displaying an object: Error: package ‘vctrs’ was installed before R 4.0.0: please re-install it
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %%
rbu_tour <- solve_TSP(rbu, method="concorde")
# Out:
# Used control parameters:
# clo	 =
# exe	 =  /home/LC/mailo01/concorde/TSP/concorde
# precision	 =  6
# verbose	 =  TRUE
# keep_files	 =  FALSE

# %%
rbu_tour
print(tour_length(rbu_tour))
plot(rbu, rbu_tour)
# Out:
# object of class ‘TOUR’
# result of method ‘concorde’ for 737 cities
# tour length: 11745.71
# [1] 11745.71
# plot without title

# %%
ans <- read_TSPLIB("/home/LC/mailo01/concorde/TSP/rbu737.sol")
# Out:
# Error in if (substr(info$TYPE, 1, 3) == "TSP") type <- "TSP" else if (substr(info$TYPE, : argument is of length zero
# Traceback:
#
# 1. read_TSPLIB("/home/LC/mailo01/concorde/TSP/rbu737.sol")

# %%
diff <- length(rbu)/2
for (i in 1:diff){
    print(c(i, rbu[i], rbu[i+diff]))
}
# Out:
# [1]  1  0 13
# [1]  2  0 25
# [1]  3  0 37
# [1]  4  0 38
# [1]  5  0 49
# [1]  6  0 50
# [1]  7  0 56
# [1]  8  0 61
# [1]  9  0 62
# [1] 10  0 74
# [1] 11  0 86
# [1] 12  0 98
# [1] 13  2 18
# [1] 14  2 20
# [1] 15  2 24
# [1] 16  2 26
# [1] 17  2 49
# [1] 18  2 51
# [1] 19  2 52
# [1] 20  2 55
# [1] 21  2 57
# [1] 22  2 67
# [1] 23  2 68
# [1] 24  2 74
# [1] 25  2 90
# [1]  26   5 102
# [1]  27   5 106
# [1] 28  5 12
# [1] 29  5 24
# [1] 30  5 26
# [1] 31  5 31
# [1] 32  5 37
# [1] 33  5 41
# [1] 34  5 46
# [1] 35  5 52
# [1] 36  5 71
# [1] 37  5  8
# [1] 38  5 95
# [1] 39  5 98
# [1] 40  8 38
# [1] 41  8 49
# [1] 42  9 12
# [1] 43  9 49
# [1] 44  9  5
# [1] 45  9 52
# [1] 46  9  8
# [1] 47 10 10
# [1] 48 10 23
# [1] 49 10 50
# [1] 50 10 54
# [1] 51 10 56
# [1] 52 10  6
# [1] 53 11 14
# [1] 54 11 23
# [1] 55 11 49
# [1] 56 11 56
# [1] 57 11 70
# [1] 58 11 80
# [1] 59 11 93
# [1] 60 11 96
# [1]  61  12 103
# [1] 62 12 28
# [1]  63  15 106
# [1] 64 15 11
# [1] 65 15 24
# ...

# %%
checklist <- c(1:diff)
## have to install package "sets"

# %%
example <- read_TSPLIB("/home/LC/mailo01/TSP-ML-Approach/src/firstRun/example.tsp")
example
# Out:
# ERROR while rich displaying an object: Error: package ‘vctrs’ was installed before R 4.0.0: please re-install it
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %%
example_tour <- solve_TSP(example, method="concorde", control = list(clo= "-vV"))
# Out:
# Used control parameters:
# clo	 =  -vV
# exe	 =  /home/LC/mailo01/concorde/TSP/concorde
# precision	 =  6
# verbose	 =  TRUE
# keep_files	 =  FALSE

# %%
example_tour
tour_length(example_tour)
# Out:
# object of class ‘TOUR’
# result of method ‘concorde’ for 100 cities
# tour length: 977.3057
# [1] 977.3057

# %% [markdown]
# results when running on terminal:
# -optimal route = 788
# -route sequence:
# 100
# 0 38 46 77 67 97 12 61 27 2
# 79 69 30 68 31 32 74 5 40 22
# 85 25 87 15 23 98 6 64 58 18
# 41 29 44 70 60 76 1 21 84 36
# 83 55 7 49 47 72 17 93 90 37
# 9 14 96 11 50 33 26 86 57 54
# 81 53 35 28 75 20 66 94 8 42
# 88 71 16 65 10 95 52 78 91 4
# 80 13 45 73 99 92 63 34 62 89

# %%
plot(example, example_tour)
## as one can see, the graph is very stiched up. The output executed in R environment gives something that is entirely not Concorde. (plus this results changes everytime)
# Out:
# plot without title

# %%
ten <- read_TSPLIB("/home/LC/mailo01/TSP-ML-Approach/src/R/Isolated-Tests/test_10pts.tsp")
ten
# Out:
# ERROR while rich displaying an object: Error: package ‘vctrs’ was installed before R 4.0.0: please re-install it
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %%
tour <- solve_TSP(ten, method="concorde")
# Out:
# Used control parameters:
# clo	 =
# exe	 =  /home/LC/mailo01/concorde/TSP/concorde
# precision	 =  6
# verbose	 =  TRUE
# keep_files	 =  FALSE

# %%
tour
tour_length(tour)
# Out:
# object of class ‘TOUR’
# result of method ‘concorde’ for 10 cities
# tour length: 356.1356
# [1] 356.1356

# %%
plot(ten, tour)
# Out:
# plot without title

# %%
## terminal result
result <- as.integer(c(1, 10, 5, 7, 6, 4, 9, 3, 8, 2))

# %%
terminal_tour <- as.TOUR(result)
plot(ten, terminal_tour)
# Out:
# plot without title
